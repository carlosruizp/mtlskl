# %%
import numpy as np
from mtlskl.data.MTLSyntheticDataset import MTLSyntheticDataset

import matplotlib.pyplot as plt

# %%
mtlds = MTLSyntheticDataset()

X, y = mtlds.X, mtlds.y

# %%
plt.scatter(X, y)
